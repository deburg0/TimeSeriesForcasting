# %% [markdown]
# <a href="https://colab.research.google.com/github/deburg0/TimeSeriesForcasting/blob/main/Lorenz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy import integrate
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import odeint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

rcParams.update({'font.size': 18})
plt.rcParams['figure.figsize'] = [12, 12]

dt = 0.01
T = 8
t = np.arange(0,T+dt,dt)
beta = 8/3
sigma = 10
rho = 28


nn_input = np.zeros((100*(len(t)-1),3))
nn_output = np.zeros_like(nn_input)

fig,ax = plt.subplots(1,1,subplot_kw={'projection': '3d'})


def lorenz_deriv(x_y_z, t0, sigma=sigma, beta=beta, rho=rho):
    x, y, z = x_y_z
    return [sigma * (y - x), x * (rho - z) - y, x * y - beta * z]

np.random.seed(123)
x0 = -15 + 30 * np.random.random((100, 3))

x_t = np.asarray([integrate.odeint(lorenz_deriv, x0_j, t)
                  for x0_j in x0])

for j in range(100):
    nn_input[j*(len(t)-1):(j+1)*(len(t)-1),:] = x_t[j,:-1,:]
    nn_output[j*(len(t)-1):(j+1)*(len(t)-1),:] = x_t[j,1:,:]
    x, y, z = x_t[j,:,:].T
    ax.plot(x, y, z,linewidth=1)
    ax.scatter(x0[j,0],x0[j,1],x0[j,2],color='r')

ax.view_init(18, -113)
plt.show()

# %%
# Define function to generate training data
def generate_data(rho, n_samples=100):
    np.random.seed(123)
    x0 = -15 + 30 * np.random.random((n_samples, 3))
    x_t = np.asarray([odeint(lorenz_deriv, x0_j, t) for x0_j in x0])
    x = x_t[:, :-1, :]
    y = x_t[:, 1:, :]
    return x.reshape(-1, 3), y.reshape(-1, 3)

# Create NN model
model = Sequential()
model.add(Dense(64, input_dim=3, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(3))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model for rho = 10
rho = 10
x_train, y_train = generate_data(rho)
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Train the model for rho = 28
rho = 28
x_train, y_train = generate_data(rho)
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Train the model for rho = 40
rho = 40
x_train, y_train = generate_data(rho)
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 16.4668 - val_loss: 0.0900
# Epoch 2/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0435 - val_loss: 0.0639
# Epoch 3/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0276 - val_loss: 0.0352
# Epoch 4/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0223 - val_loss: 0.0818
# Epoch 5/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0169 - val_loss: 0.0232
# Epoch 6/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0135 - val_loss: 0.0504
# Epoch 7/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0137 - val_loss: 0.0175
# Epoch 8/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0117 - val_loss: 0.0147
# Epoch 9/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0094 - val_loss: 0.0147
# Epoch 10/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0103 - val_loss: 0.0085
# Epoch 11/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0086 - val_loss: 0.0151
# Epoch 12/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0091 - val_loss: 0.0141
# Epoch 13/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 14/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0071 - val_loss: 0.0079
# Epoch 15/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0063 - val_loss: 0.0092
# Epoch 16/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0068 - val_loss: 0.0099
# Epoch 17/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0057 - val_loss: 0.0063
# Epoch 18/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0056 - val_loss: 0.0070
# Epoch 19/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0059 - val_loss: 0.0067
# Epoch 20/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - loss: 0.0055 - val_loss: 0.0071
# Epoch 21/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0047 - val_loss: 0.0049
# Epoch 22/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0049 - val_loss: 0.0075
# Epoch 23/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 24/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0050 - val_loss: 0.0067
# Epoch 25/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 26/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 27/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0039 - val_loss: 0.0047
# Epoch 28/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0039 - val_loss: 0.0082
# Epoch 29/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 30/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 31/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0033 - val_loss: 0.0099
# Epoch 32/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0037 - val_loss: 0.0051
# Epoch 33/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0032 - val_loss: 0.0072
# Epoch 34/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0031 - val_loss: 0.0051
# Epoch 35/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 36/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0031 - val_loss: 0.0048
# Epoch 37/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0035 - val_loss: 0.0059
# Epoch 38/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 39/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 40/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 41/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 42/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 43/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 44/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 45/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0025 - val_loss: 0.0072
# Epoch 46/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0033 - val_loss: 0.0053
# Epoch 47/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 48/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 49/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0023 - val_loss: 0.0042
# Epoch 50/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 1/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0025 - val_loss: 0.0046
# Epoch 2/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 3/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 4/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 5/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 6/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 7/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 8/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 9/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 10/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 11/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 12/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 13/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 14/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 15/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 16/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 17/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 18/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 19/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 20/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 21/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 22/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 23/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 24/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 25/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 26/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 27/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 28/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 29/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 30/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 31/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 32/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 33/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 34/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 35/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 36/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 37/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 38/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 39/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0018 - val_loss: 0.0014
# Epoch 40/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 41/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 42/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 43/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 44/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 45/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 46/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 47/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 48/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 49/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 50/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 1/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 2/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 3/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 4/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 5/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 6/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 7/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 8/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 9/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 10/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 11/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 12/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 13/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 14/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 15/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0017 - val_loss: 0.0051
# Epoch 16/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 17/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 18/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 19/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 20/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 21/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 22/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 23/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0015 - val_loss: 0.0049
# Epoch 24/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 25/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 26/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 27/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 28/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 29/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 30/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 31/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 32/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 33/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 34/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 35/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 36/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 37/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 38/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 39/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 40/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - loss: 0.0018 - val_loss: 0.0046
# Epoch 41/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 42/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 43/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 44/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 45/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 46/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.0016 - val_loss: 0.0069
# Epoch 47/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 48/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 49/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 50/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0015 - val_loss: 0.0022

# %%
# Evaluate the model for rho values of 17 and 35
fig = plt.figure(figsize=(10, 10))
for i, rho in enumerate([17, 35]):
    x_test, y_test = generate_data(rho)
    y_pred = model.predict(x_test)

    ax = fig.add_subplot(2, 2, i+1, projection='3d')
    ax.plot(x_test[:, 0], x_test[:, 1], x_test[:, 2], 'b', label='Actual')
    ax.plot(y_pred[:, 0], y_pred[:, 1], y_pred[:, 2], '--', label='Predicted')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title(f'Lorenz system for rho = {rho}')
    ax.legend()

plt.show()
# Out:
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %%
def generate_data(x_t, dt, rho_values):
    X = []
    y = []
    for i, rho in enumerate(rho_values):
        for j in range(x_t.shape[0]):
            for k in range(1, x_t.shape[1]):
                if k < len(t)-1:
                    X.append(np.hstack((x_t[j,k,:], rho)))
                    y.append(x_t[j,k+1,:])
    X = np.array(X)
    y = np.array(y)
    return X, y

rho_values = [10, 28, 40]
X_train, y_train = generate_data(x_t, dt, rho_values)

# %%
# LSTM
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Define the LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(128, input_shape=(4, 1)))
model_lstm.add(Dense(3))

# Compile the model
model_lstm.compile(loss='mean_squared_error', optimizer='adam')

# Reshape the training data to match the input shape of the LSTM model
X_train_lstm = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# Train the LSTM model
model_lstm.fit(X_train_lstm, y_train, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 3746/3746 [==============================] - 18s 4ms/step - loss: 5.9355
# Epoch 2/100
# 3746/3746 [==============================] - 17s 5ms/step - loss: 0.0280
# Epoch 3/100
# 3746/3746 [==============================] - 28s 7ms/step - loss: 0.0115
# Epoch 4/100
# 3746/3746 [==============================] - 16s 4ms/step - loss: 0.0083
# Epoch 5/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0078
# Epoch 6/100
# 3746/3746 [==============================] - 18s 5ms/step - loss: 0.0065
# Epoch 7/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0061
# Epoch 8/100
# 3746/3746 [==============================] - 17s 5ms/step - loss: 0.0051
# Epoch 9/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0053
# Epoch 10/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0047
# Epoch 11/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0047
# Epoch 12/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0042
# Epoch 13/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0046
# Epoch 14/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0038
# Epoch 15/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0039
# Epoch 16/100
# 3746/3746 [==============================] - 18s 5ms/step - loss: 0.0037
# Epoch 17/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0036
# Epoch 18/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0034
# Epoch 19/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0033
# Epoch 20/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0032
# Epoch 21/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0029
# Epoch 22/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0028
# Epoch 23/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0027
# Epoch 24/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0027
# Epoch 25/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0026
# Epoch 26/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0026
# Epoch 27/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0024
# Epoch 28/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0026
# Epoch 29/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0022
# Epoch 30/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0022
# Epoch 31/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0025
# Epoch 32/100
# 3746/3746 [==============================] - 18s 5ms/step - loss: 0.0022
# Epoch 33/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0021
# Epoch 34/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0021
# Epoch 35/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0022
# Epoch 36/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0020
# Epoch 37/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0020
# Epoch 38/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0021
# Epoch 39/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0020
# Epoch 40/100
# 3746/3746 [==============================] - 24s 6ms/step - loss: 0.0018
# Epoch 41/100
# 3746/3746 [==============================] - 18s 5ms/step - loss: 0.0019
# Epoch 42/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0018
# Epoch 43/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0017
# Epoch 44/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0018
# Epoch 45/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0017
# Epoch 46/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0017
# Epoch 47/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0017
# Epoch 48/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0016
# Epoch 49/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0017
# Epoch 50/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0016
# Epoch 51/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0016
# Epoch 52/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0015
# Epoch 53/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0015
# Epoch 54/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0016
# Epoch 55/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0015
# Epoch 56/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0015
# Epoch 57/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0015
# Epoch 58/100
# 3746/3746 [==============================] - 23s 6ms/step - loss: 0.0015
# Epoch 59/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0015
# Epoch 60/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0014
# Epoch 61/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0014
# Epoch 62/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0013
# Epoch 63/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0013
# Epoch 64/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0013
# Epoch 65/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0012
# Epoch 66/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0014
# Epoch 67/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0013
# Epoch 68/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0013
# Epoch 69/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0013
# Epoch 70/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0013
# Epoch 71/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0012
# Epoch 72/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0012
# Epoch 73/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0012
# Epoch 74/100
# 3746/3746 [==============================] - 27s 7ms/step - loss: 0.0011
# Epoch 75/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 0.0011
# Epoch 76/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0012
# Epoch 77/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0012
# Epoch 78/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0011
# Epoch 79/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0012
# Epoch 80/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0011
# Epoch 81/100
# 3746/3746 [==============================] - 23s 6ms/step - loss: 0.0012
# Epoch 82/100
# 3746/3746 [==============================] - 27s 7ms/step - loss: 0.0011
# Epoch 83/100
# 3746/3746 [==============================] - 25s 7ms/step - loss: 0.0012
# Epoch 84/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0011
# Epoch 85/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0011
# Epoch 86/100
# 3746/3746 [==============================] - 25s 7ms/step - loss: 0.0011
# Epoch 87/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 9.9292e-04
# Epoch 88/100
# 3746/3746 [==============================] - 25s 7ms/step - loss: 0.0011
# Epoch 89/100
# 3746/3746 [==============================] - 23s 6ms/step - loss: 0.0010
# Epoch 90/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0010
# Epoch 91/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 0.0011
# Epoch 92/100
# 3746/3746 [==============================] - 24s 6ms/step - loss: 0.0010
# Epoch 93/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 9.8619e-04
# Epoch 94/100
# 3746/3746 [==============================] - 22s 6ms/step - loss: 0.0010
# Epoch 95/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 9.8196e-04
# Epoch 96/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0010
# Epoch 97/100
# 3746/3746 [==============================] - 21s 5ms/step - loss: 9.4921e-04
# Epoch 98/100
# 3746/3746 [==============================] - 21s 6ms/step - loss: 8.9801e-04
# Epoch 99/100
# 3746/3746 [==============================] - 19s 5ms/step - loss: 0.0011
# Epoch 100/100
# 3746/3746 [==============================] - 20s 5ms/step - loss: 9.0784e-04

# %%
# RNN
# Define the RNN model
model_rnn = Sequential()
model_rnn.add(Dense(128, input_shape=(4,)))
model_rnn.add(Dense(3))

# Compile the model
model_rnn.compile(loss='mean_squared_error', optimizer='adam')

# Train the RNN model
model_rnn.fit(X_train, y_train, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 3746/3746 [==============================] - 4s 911us/step - loss: 1.1572
# Epoch 2/100
# 3746/3746 [==============================] - 4s 955us/step - loss: 0.3281
# Epoch 3/100
# 3746/3746 [==============================] - 3s 905us/step - loss: 0.3275
# Epoch 4/100
# 3746/3746 [==============================] - 4s 956us/step - loss: 0.3266
# Epoch 5/100
# 3746/3746 [==============================] - 3s 882us/step - loss: 0.3242
# Epoch 6/100
# 3746/3746 [==============================] - 3s 866us/step - loss: 0.3212
# Epoch 7/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3202
# Epoch 8/100
# 3746/3746 [==============================] - 3s 932us/step - loss: 0.3191
# Epoch 9/100
# 3746/3746 [==============================] - 3s 890us/step - loss: 0.3177
# Epoch 10/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3173
# Epoch 11/100
# 3746/3746 [==============================] - 3s 828us/step - loss: 0.3159
# Epoch 12/100
# 3746/3746 [==============================] - 3s 825us/step - loss: 0.3149
# Epoch 13/100
# 3746/3746 [==============================] - 3s 842us/step - loss: 0.3146
# Epoch 14/100
# 3746/3746 [==============================] - 3s 901us/step - loss: 0.3150
# Epoch 15/100
# 3746/3746 [==============================] - 3s 920us/step - loss: 0.3140
# Epoch 16/100
# 3746/3746 [==============================] - 4s 950us/step - loss: 0.3131
# Epoch 17/100
# 3746/3746 [==============================] - 4s 992us/step - loss: 0.3131
# Epoch 18/100
# 3746/3746 [==============================] - 4s 942us/step - loss: 0.3135
# Epoch 19/100
# 3746/3746 [==============================] - 3s 737us/step - loss: 0.3126
# Epoch 20/100
# 3746/3746 [==============================] - 3s 868us/step - loss: 0.3119
# Epoch 21/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3127
# Epoch 22/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3122
# Epoch 23/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3114
# Epoch 24/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3114
# Epoch 25/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3107
# Epoch 26/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3103
# Epoch 27/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3110
# Epoch 28/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3112
# Epoch 29/100
# 3746/3746 [==============================] - 4s 996us/step - loss: 0.3100
# Epoch 30/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3105
# Epoch 31/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3102
# Epoch 32/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3105
# Epoch 33/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3101
# Epoch 34/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3099
# Epoch 35/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3099
# Epoch 36/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3097
# Epoch 37/100
# 3746/3746 [==============================] - 6s 1ms/step - loss: 0.3098
# Epoch 38/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3106
# Epoch 39/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3095
# Epoch 40/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3092
# Epoch 41/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3100
# Epoch 42/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3086
# Epoch 43/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3087
# Epoch 44/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3087
# Epoch 45/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3089
# Epoch 46/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3085
# Epoch 47/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3082
# Epoch 48/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3082
# Epoch 49/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3085
# Epoch 50/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3084
# Epoch 51/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3078
# Epoch 52/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3071
# Epoch 53/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3080
# Epoch 54/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3083
# Epoch 55/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3079
# Epoch 56/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3080
# Epoch 57/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3076
# Epoch 58/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3074
# Epoch 59/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3073
# Epoch 60/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3073
# Epoch 61/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3072
# Epoch 62/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3076
# Epoch 63/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3066
# Epoch 64/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3070
# Epoch 65/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3073
# Epoch 66/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3074
# Epoch 67/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3073
# Epoch 68/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3072
# Epoch 69/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3068
# Epoch 70/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3072
# Epoch 71/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3072
# Epoch 72/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3071
# Epoch 73/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3069
# Epoch 74/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3069
# Epoch 75/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3065
# Epoch 76/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3075
# Epoch 77/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3071
# Epoch 78/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3069
# Epoch 79/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3071
# Epoch 80/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3067
# Epoch 81/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3069
# Epoch 82/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3066
# Epoch 83/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3067
# Epoch 84/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3064
# Epoch 85/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3064
# Epoch 86/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3066
# Epoch 87/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3066
# Epoch 88/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3065
# Epoch 89/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3066
# Epoch 90/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3063
# Epoch 91/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3061
# Epoch 92/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3063
# Epoch 93/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3065
# Epoch 94/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3064
# Epoch 95/100
# 3746/3746 [==============================] - 4s 1ms/step - loss: 0.3061
# Epoch 96/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3062
# Epoch 97/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3057
# Epoch 98/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3071
# Epoch 99/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3065
# Epoch 100/100
# 3746/3746 [==============================] - 5s 1ms/step - loss: 0.3063

# %%
from sklearn.metrics import mean_squared_error

x0_test = -15 + 30 * np.random.random((100, 3))
rho_test = [17, 35]
x_t_test = np.asarray([integrate.odeint(lorenz_deriv, x0_j, t) for x0_j in x0_test])
X_test, y_test = generate_data(x_t_test, dt, rho_test)

# Reshape the test data to match the input shape of the LSTM model
X_test_lstm = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Use the trained LSTM model to make predictions on the test data
y_pred_lstm = model_lstm.predict(X_test_lstm)

# Use the trained RNN model to make predictions on the test data
y_pred_rnn = model_rnn.predict(X_test)

# Calculate the mean squared error for the LSTM model
mse_lstm = mean_squared_error(y_test, y_pred_lstm)
print('LSTM MSE:', mse_lstm)

# Calculate the mean squared error for the RNN model
mse_rnn = mean_squared_error(y_test, y_pred_rnn)
print('RNN MSE:', mse_rnn)
# Out:
# 4994/4994 [==============================] - 6s 1ms/step
# 4994/4994 [==============================] - 3s 597us/step
# LSTM MSE: 0.0031942127091748097
# RNN MSE: 0.3095720377747974
